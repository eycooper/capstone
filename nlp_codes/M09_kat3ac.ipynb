# %% [markdown]
# # Module 9: Word2Vec
#
# * Grace Lyons
# * kat3ac

# %% [markdown]
# # Set Up

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)

data_dir = '/content/drive/My Drive/DS_5001/MOD9/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Configuration

# %%
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']
BAG = OHCO[:3] # Paragraphs
# BAG = OHCO[:4] # Sentences
window = 5

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from gensim.models import word2vec
from sklearn.manifold import TSNE
# !pip install plotly_express
import plotly_express as px
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plotly_express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (1.7.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (0.12.2)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (0.5.3)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (5.5.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (1.21.6)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.0->plotly_express) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.0->plotly_express) (2022.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->plotly_express) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.1.0->plotly_express) (8.1.0)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1

# %%
# %matplotlib inline

# %% [markdown]
# # Process

# %% [markdown]
# ## Import TOKENS and convert to a corpus for Gensim
#
# We import data from the TOKEN table of the novels corpus, excluding proper nouns.

# %%
TOKENS = pd.read_csv(data_dir + 'TOKEN2.csv')

# %%
TOKENS.head()
# Out:
#    book_id  chap_num  para_num  sent_num  token_num             pos_tuple  \
# 0      158         1         1         0          0       ('Emma', 'NNP')
# 1      158         1         1         0          1  ('Woodhouse', 'NNP')
# 2      158         1         1         0          3    ('handsome', 'NN')
# 3      158         1         1         0          5      ('clever', 'NN')
# 4      158         1         1         0          7         ('and', 'CC')
#
#    pos  token_str   term_str  term_id
# 0  NNP       Emma       emma    11614
# 1  NNP  Woodhouse  woodhouse    39340
# 2   NN   handsome   handsome    15924
# 3   NN     clever     clever     6354
# 4   CC        and        and     1426

# %%
LIB = pd.read_csv(data_dir + 'LIB.csv')
LIB.head()
# Out:
#    book_id                                         book_title  \
# 0      158                               Emma, by Jane Austen
# 1      946                         Lady Susan, by Jane Austen
# 2     1212  Love And Freindship And Other Early Works, by ...
# 3      141                     Mansfield Park, by Jane Austen
# 4      121                   Northanger Abbey, by Jane Austen
#
#                                            book_file  author  \
# 0                   epubs/AUSTEN_JANE_EMMA-pg158.txt  austen
# 1             epubs/AUSTEN_JANE_LADY_SUSAN-pg946.txt  austen
# 2  epubs/AUSTEN_JANE_LOVE_AND_FREINDSHIP_SIC_-pg1...  austen
# 3         epubs/AUSTEN_JANE_MANSFIELD_PARK-pg141.txt  austen
# 4       epubs/AUSTEN_JANE_NORTHANGER_ABBEY-pg121.txt  austen
#
#                                        title
# 0                                       Emma
# 1                                 Lady Susan
# 2  Love And Freindship And Other Early Works
# 3                             Mansfield Park
# 4                           Northanger Abbey

# %%
TOKENS = pd.merge(TOKENS, LIB, on = ['book_id'])\
                .drop(['book_title', 'book_file', 'title'], axis = 1)\
                .set_index(OHCO)

# %%
TOKENS.head()
# Out:
#                                                          pos_tuple  pos  \
# book_id chap_num para_num sent_num token_num
# 158     1        1        0        0               ('Emma', 'NNP')  NNP
#                                    1          ('Woodhouse', 'NNP')  NNP
#                                    3            ('handsome', 'NN')   NN
#                                    5              ('clever', 'NN')   NN
#                                    7                 ('and', 'CC')   CC
#
#                                               token_str   term_str  term_id  \
# book_id chap_num para_num sent_num token_num
# 158     1        1        0        0               Emma       emma    11614
#                                    1          Woodhouse  woodhouse    39340
#                                    3           handsome   handsome    15924
#                                    5             clever     clever     6354
#                                    7                and        and     1426
#
#                                               author
# book_id chap_num para_num sent_num token_num
# 158     1        1        0        0          austen
#                                    1          austen
#                                    3          austen
#                                    5          austen
#                                    7          austen

# %%
AUSTEN = TOKENS[TOKENS.author == 'austen']
AUSTEN.head()
# Out:
#                                                          pos_tuple  pos  \
# book_id chap_num para_num sent_num token_num
# 158     1        1        0        0               ('Emma', 'NNP')  NNP
#                                    1          ('Woodhouse', 'NNP')  NNP
#                                    3            ('handsome', 'NN')   NN
#                                    5              ('clever', 'NN')   NN
#                                    7                 ('and', 'CC')   CC
#
#                                               token_str   term_str  term_id  \
# book_id chap_num para_num sent_num token_num
# 158     1        1        0        0               Emma       emma    11614
#                                    1          Woodhouse  woodhouse    39340
#                                    3           handsome   handsome    15924
#                                    5             clever     clever     6354
#                                    7                and        and     1426
#
#                                               author
# book_id chap_num para_num sent_num token_num
# 158     1        1        0        0          austen
#                                    1          austen
#                                    3          austen
#                                    5          austen
#                                    7          austen

# %%
MELVILLE = TOKENS[TOKENS.author == 'melville']
MELVILLE.head()
# Out:
#                                                           pos_tuple  pos  \
# book_id chap_num para_num sent_num token_num
# 15422   1        0        0        0                  ('THE', 'DT')   DT
#                                    1          ('BIRTHPLACE', 'NNP')  NNP
#                                    2                  ('OF', 'NNP')  NNP
#                                    3              ('ISRAEL', 'NNP')  NNP
#                  1        0        0                  ('The', 'DT')   DT
#
#                                                token_str    term_str  term_id  \
# book_id chap_num para_num sent_num token_num
# 15422   1        0        0        0                 THE         the    34777
#                                    1          BIRTHPLACE  birthplace     3662
#                                    2                  OF          of    23891
#                                    3              ISRAEL      israel    18985
#                  1        0        0                 The         the    34777
#
#                                                 author
# book_id chap_num para_num sent_num token_num
# 15422   1        0        0        0          melville
#                                    1          melville
#                                    2          melville
#                                    3          melville
#                  1        0        0          melville

# %%
corpus_a = AUSTEN[~AUSTEN.pos.str.match('NNPS?')]\
    .groupby(BAG)\
    .term_str.apply(lambda  x:  x.tolist())\
    .reset_index()['term_str'].tolist()

# %%
corpus_m = MELVILLE[~MELVILLE.pos.str.match('NNPS?')]\
    .groupby(BAG)\
    .term_str.apply(lambda  x:  x.tolist())\
    .reset_index()['term_str'].tolist()

# %% [markdown]
# ## Generate word embeddings with Gensim's library

# %%
model_a = word2vec.Word2Vec(corpus_a, size=246, window=window, min_count=200, workers=4)
model_m = word2vec.Word2Vec(corpus_m, size=246, window=window, min_count=200, workers=4)
# Out:
# WARNING:gensim.models.base_any2vec:consider setting layer size to a multiple of 4 for greater performance
# WARNING:gensim.models.base_any2vec:consider setting layer size to a multiple of 4 for greater performance

# %% [markdown]
# ## Visualize with tSNE

# %% [markdown]
# ### Generate coordinates to plot

# %%
coords_a = pd.DataFrame(index=range(len(model_a.wv.vocab)))
coords_a['label'] = [w for w in model_a.wv.vocab]
coords_a['vector'] = coords_a['label'].apply(lambda x: model_a.wv.get_vector(x))

# %%
coords_a.head()
# Out:
#   label                                             vector
# 0    of  [0.3226378, 0.10830974, 0.36938196, -0.3088802...
# 1    in  [0.34731096, -0.26975662, 0.6065102, -0.030056...
# 2   was  [0.44936335, -0.31799895, 0.6100802, 0.484167,...
# 3     a  [0.07964127, 0.07697755, -0.3564742, -0.183003...
# 4   man  [-0.7001643, -0.3426114, -1.1465791, 0.6497261...

# %%
coords_m = pd.DataFrame(index=range(len(model_m.wv.vocab)))
coords_m['label'] = [w for w in model_m.wv.vocab]
coords_m['vector'] = coords_m['label'].apply(lambda x: model_m.wv.get_vector(x))

# %%
coords_m.head()
# Out:
#   label                                             vector
# 0   the  [0.014728041, 0.2173266, 0.48286474, -0.256540...
# 1   for  [0.20142768, -0.50761616, -0.5495971, 0.110741...
# 2     a  [0.06193759, 0.097066, -0.040272556, -0.152646...
# 3    of  [-0.05318928, -0.12785444, 0.002418933, -0.001...
# 4     s  [0.016910266, -0.1649269, -0.31504172, 0.26374...

# %% [markdown]
# ### Use ScikitLearn's TSNE library

# %%
tsne_model_a = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
tsne_values_a = tsne_model_a.fit_transform(coords_a['vector'].tolist())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
coords_a['x'] = tsne_values_a[:,0]
coords_a['y'] = tsne_values_a[:,1]

# %%
coords_a.head()
# Out:
#   label                                             vector          x  \
# 0    of  [0.3226378, 0.10830974, 0.36938196, -0.3088802...  -1.066439
# 1    in  [0.34731096, -0.26975662, 0.6065102, -0.030056...  -1.322900
# 2   was  [0.44936335, -0.31799895, 0.6100802, 0.484167,...   8.254866
# 3     a  [0.07964127, 0.07697755, -0.3564742, -0.183003...  14.922655
# 4   man  [-0.7001643, -0.3426114, -1.1465791, 0.6497261...  -8.926122
#
#           y
# 0  5.098060
# 1  4.525282
# 2  3.541362
# 3  1.434503
# 4  3.544481

# %%
tsne_model_m = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
tsne_values_m = tsne_model_m.fit_transform(coords_m['vector'].tolist())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
coords_m['x'] = tsne_values_m[:,0]
coords_m['y'] = tsne_values_m[:,1]

# %%
coords_m.head()
# Out:
#   label                                             vector         x         y
# 0   the  [0.014728041, 0.2173266, 0.48286474, -0.256540...  5.362400 -6.849661
# 1   for  [0.20142768, -0.50761616, -0.5495971, 0.110741... -3.228860  2.338336
# 2     a  [0.06193759, 0.097066, -0.040272556, -0.152646... -1.341510 -6.300092
# 3    of  [-0.05318928, -0.12785444, 0.002418933, -0.001... -3.500493 -5.596595
# 4     s  [0.016910266, -0.1649269, -0.31504172, 0.26374...  4.679792 -1.528852

# %% [markdown]
# ### Plot the coordinates

# %%
px.scatter(coords_a, 'x', 'y', text='label', height=1000).update_traces(mode='text')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9a457624-f6a8-44a9-b90a-b58ebd382ccf" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a457624-f6a8-44a9-b90a-b58ebd382ccf")) {                    Plotly.newPlot(                        "9a457624-f6a8-44a9-b90a-b58ebd382ccf",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>label=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"text","name":"","orientation":"v","showlegend":false,"text":["of","in","was","a","man","who","for","his","own","never","took","up","any","but","the","there","he","found","an","hour","and","one","were","into","by","from","as","over","almost","last","if","every","other","could","read","with","interest","which","this","at","always","married","daughter","lady","has","still","son","such","had","s","it","himself","family","these","words","after","most","day","on","wife","then","how","been","first","settled","three","year","all","they","two","again","great","end","character","person","situation","very","fine","few","think","more","their","appearance","than","did","nor","new","made","be","place","only","to","object","good","attachment","since","them","must","have","thing","woman","whose","might","her","afterwards","she","or","real","years","though","not","being","world","herself","enough","friends","children","life","make","no","matter","when","called","mother","rather","father","however","friend","brought","kindness","best","help","giving","marry","that","head","acquaintance","passed","away","near","well","should","thought","marriage","is","does","known","like","having","met","dear","would","really","given","much","do","possible","gone","together","little","mind","people","either","sister","word","give","way","indeed","before","pretty","girl","even","its","so","different","eyes","nothing","now","hope","ever","name","rest","old","country","fortune","therefore","received","neither","ill","time","same","least","half","thinking","else","see","about","long","him","quite","equal","seen","idea","doing","down","home","immediately","out","some","satisfied","felt","within","next","take","once","left","present","while","young","soon","brother","making","back","just","engaged","agreeable","talked","expected","came","town","come","house","ought","hand","longer","between","whom","feelings","yet","perhaps","reason","suppose","done","kind","another","added","knew","state","right","less","what","often","far","say","can","we","you","set","off","room","happy","themselves","whole","obliged","able","means","without","part","power","both","seemed","something","leave","sense","subject","gave","coming","manners","side","those","husband","sisters","deal","under","doubt","others","against","wanted","everything","your","said","looking","may","will","i","true","many","our","saw","anything","short","hardly","through","too","taken","put","comfort","where","perfectly","change","entirely","looked","days","go","pleasure","seeing","course","believe","regard","spirits","certainly","let","beyond","manner","glad","wished","returned","already","love","because","attention","point","get","visit","better","affection","morning","replied","business","are","am","know","me","upon","going","among","find","look","my","care","afraid","men","assure","here","spoke","us","oh","sorry","yes","speak","talking","cried","shall","till","poor","body","moment","towards","feel","account","sure","ready","whether","continued","told","heard","hear","mean","happiness","went","walked","feeling","saying","opinion","general","began","each","walk","want","party","carriage","sort","determined","yourself","talk","wish","things","tell","understand","nature","ladies","conversation","heart","answer","why","evening","voice","dare", ...

# %% [markdown]
# In this visualization for Austen's works, one region that has similar words is the positive region of the y axis. In this area there are a lot of words that are associated with people, like eyes, friend, and father. The second region that stands out is the clusters in the fourth quadrant. These are mostly nouns and verbs like looking, room, and passed.

# %%
px.scatter(coords_m, 'x', 'y', text='label', height=1000).update_traces(mode='text')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1c212d91-649f-4a6f-86a6-4423e00d1b32" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c212d91-649f-4a6f-86a6-4423e00d1b32")) {                    Plotly.newPlot(                        "1c212d91-649f-4a6f-86a6-4423e00d1b32",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>label=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"text","name":"","orientation":"v","showlegend":false,"text":["the","for","a","of","s","at","sea","yes","as","i","live","out","sight","land","after","whale","beneath","sun","and","on","wide","above","around","nothing","else","our","were","all","there","is","not","sweet","left","those","which","once","quarter","deck","have","from","they","too","are","gone","us","but","oh","ye","state","room","sailors","who","make","so","much","about","days","across","where","day","off","five","it","was","your","hard","to","be","up","in","little","sleep","ten","hours","with","you","good","what","would","say","one","earth","no","green","thing","seen","if","even","could","this","way","that","wood","we","has","been","by","captain","long","himself","turn","young","him","among","look","now","he","his","before","water","doubt","lost","never","again","will","few","black","told","me","word","had","last","forth","poor","body","upon","table","next","night","believe","any","yet","every","may","brought","end","point","ship","can","alone","when","come","thee","thou","art","or","thy","why","truth","speak","cut","very","moment","how","see","living","old","her","more","said","right","other","found","ever","put","hand","none","lady","nt","keep","full","sir","watch","close","she","then","down","like","work","take","round","because","under","go","should","did","shore","well","sides","along","an","time","away","rest","hope","soon","within","some","my","course","strange","things","does","name","spirit","trees","blue","such","during","ground","felt","having","first","still","their","them","stone","these","scene","whose","gave","world","return","account","years","into","previous","only","anything","known","concerning","half","sure","almost","new","given","made","know","general","two","particular","frigate","however","war","book","same","short","natives","many","white","men","received","hands","peculiar","case","number","certain","took","place","beautiful","wife","seemed","its","form","far","further","together","thus","king","three","while","man","held","themselves","hundred","let","between","officer","give","board","side","making","hat","arms","struck","went","officers","high","manner","broad","face","line","eyes","person","dark","below","view","head","company","feet","open","over","fellow","wild","own","forward","turning","boats","twenty","light","towards","do","vessel","hour","true","always","best","done","forecastle","matter","against","instant","great","times","most","might","came","broken","fish","air","aloft","often","distance","eye","deep","slowly","sound","heard","looking","blood","red","till","sail","being","sailor","cabin","mate","heads","hardly","island","called","less","than","reason","fact","until","nearly","shall","part","ships","large","length","people","itself","life","nature","running","ourselves","morning","lay","here","sometimes","country","ocean","bound","saw","whole","just","taken","boat","stand","rather","gentleman","friend","main","quite","get","another","thought","each","means","something","kept","became","through","whom","death","perhaps","foot","friends","coming","arm","hair","hold","others","run","nor","possible","passed","think","free","carried","crew","evening","got","several","various","looked","four","set","fire","ashore","show","least","going","near","fine","secr ...

# %% [markdown]
# In this visualization for the Melville works, one region that stands out is around the midpoint on the y axis in the negative region of the x axis. There seems to be a lot of uncertain words like sometimes, whatever, and perhaps. Another region that stands out is a small cluster of words in the first quadrant that are all time related like years, days, and hours.

# %% [markdown]
# A few analogies between Melville's work and Austen's work is they both use very descriptive language; they both have a lot of personal language like me, her, and him; and lastly, they also both use a lot of indecisive language like seems, doubt, and might.
