# %% [markdown]
# # Module 8: LDA From Scatch
#
# We develop an LDA topic modeler using collapsed Gibbs sample as described by [Griffiths and Steyvers (2004)](https://collab.its.virginia.edu/access/content/group/b9e58ce7-0f44-48fe-9861-b7a7657f551a/Articles/sciencetopics.pdf).

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import re
from nltk.corpus import stopwords

# %% [markdown]
# # Functions

# %% [markdown]
# ## Convert F1 Corpus
#
# We convert the F1 corpus into TOKEN and VOCAB tables.

# %%
def convert_corpus(docs):
    
    global TOKEN, VOCAB
    
    # Convert docs into tokens
    stop_words = set(stopwords.words('english')) 
    tokens = []
    for i, doc in enumerate(docs):
        for j, token in enumerate(doc.split()):
            term_str = re.sub(r'[\W_]+', '', token).lower()
            if term_str not in stop_words:
                tokens.append((i, j, term_str))
    TOKEN = pd.DataFrame(tokens, columns=['doc_id','token_num','term_str'])\
        .set_index(['doc_id','token_num'])
    
    # Extract vocabulary
    VOCAB = TOKEN.term_str.value_counts().to_frame().reset_index()
    VOCAB.columns = ['term_str', 'n']
    VOCAB.index.name = 'term_id'
    TOKEN['term_id'] = TOKEN.term_str.map(VOCAB.reset_index().set_index('term_str').term_id)

# %% [markdown]
# ## Initialize the Model
#
# We convert TOKEN into a BOW, randomly assign topic labels, and generate PHI and THETA tables.

# %%
def init_model():
    
    global n_topics, n_docs, n_words, TOKEN, BOW, TOPIC, THETA, PHI, topic_names

    # Extract BOW from TOKEN
    BOW = TOKEN.groupby(['doc_id', 'term_id']).term_id.count()\
        .to_frame().rename(columns={'term_id':'n'})
    
    # Normalize n
    # May want normalize n to binary or log form
    
    # Create TOPIC table
    TOPIC = pd.DataFrame(index=range(n_topics))
    TOPIC.index.name = 'topic_id'
    topic_names = TOPIC.index.tolist()
    
    # Randomly assign topics to words (word = term in BOW)
    BOW['topic_id'] = TOPIC.sample(BOW.shape[0], replace=True).index
    
    # Generete topic-doc count matrix
    THETA = BOW.groupby(['topic_id', 'doc_id']).n.sum()\
        .unstack().fillna(0).astype('int')

    # Generate term-topic matrix (aka word-topic)
    PHI = BOW.groupby(['term_id', 'topic_id']).n.sum()\
        .unstack().fillna(0).astype('int')        

    # Get doc and word counts
    n_docs = THETA.shape[1]
    n_words = PHI.shape[0]

# %% [markdown]
# ## Gibbs Sampler
#
# We sample each document and word combination in the BOW table. In each case,
# we are looking for two values:
#
# * the topic with which a word has been most frequently labeled
# * the topic with which the document has the most labeled words
#
# We combine these values in order to align the label of the current word with the rest of the data.\
# If a the topic is highly associated with both the word and the document, then that topic will get a high value.
#
# Note that all that is going on here is a sorting operation -- the random assignment does not predict anything.\
# Instead, we are just gathering words under topics and topics under documents.

# %%
def gibbs_sample(d, w):
    
    global n_topics, n_docs, n_words, BOW, PHI, THETA, alpha, beta, topic_names
    
    # Get current topic for word in doc
    z1 = BOW.at[(d, w), 'topic_id']
    
    # Get the number of tokens for the word
    n = BOW.at[(d, w), 'n']
    
    # Remove current assignment from the counts
    PHI.at[w, z1] -= n
    THETA.at[z1, d] -= n

    # Sample from the two count matrices
    weights = np.zeros(n_topics)
    for t in topic_names:
        
        # How much this word is currently labeled by each topic
        P = (PHI.at[w, t] + alpha) / (PHI[t].sum() + n_words * alpha)
        
        # How much each topic currently appears in this document
        T = (THETA.at[t, d] + beta) / (THETA[d].sum() + n_topics * beta)
        
        # The combined value of P and T.
        weights[t] = P * T
            
    # Alternate. These operations marginalize over topics; no need to iterate
    # P = (PHI.loc[w] + alpha) / (PHI.sum() + n_words * alpha)
    # T = (THETA[d] + beta) / (THETA[d].sum() + n_topics * beta)
    # weights = (P * T).values

    # Draw new topic value from weighted list of topics
    pwgt = weights / weights.sum()
    z2 = np.random.choice(topic_names, p=pwgt)
    
    # Apply the value of the word to the topic  
    PHI.at[w, z2] += n
    THETA.at[z2, d] += n
        
    # Update the topic assignment
    BOW.at[(d , w), 'topic_id'] = z2

# %% [markdown]
# ## Show Results
#
# We present a summary view of  words associated with topics and topics associated with documents.

# %%
def show_results():
    
    global VOCAB, TOPIC, THETA, PHI, topic_names, docs
        
    P = PHI[topic_names] / PHI[topic_names].sum()
    
    P['term_str'] = VOCAB.term_str 
    for t in topic_names:
        top_terms = P.sort_values(t, ascending=False).head(10)[[t, 'term_str']]
        print('-' * 80)
        print(top_terms)
        # Could add a string to TOPIC.loc[t, 'top_terms'] to demonstrateuse of tables to capture information.
    
    print('-' * 80)
    
    DOC = THETA.T
    DOC['doc'] = docs
    print(DOC.head(1000))
    
    print('-' * 80)

# %% [markdown]
# # Demonstration
#
# We use a toy example to see if the method works.\
# Because our codd is not vert efficient, we just

# %% [markdown]
# ## Data
#
# A small F1 corpus.

# %%
docs = """
I ate a banana and a spinach smoothie for breakfast.
I like to eat broccoli and bananas.
Chinchillas and kittens are cute.
My sister adopted a kitten yesterday.
Look at this cute hamster munching on a piece of broccoli.
""".split("\n")[1:-1]

# %% [markdown]
# ## Parameters

# %%
n_topics = 2
n_iters = 5000
alpha = .01
beta = .1

# %% [markdown]
# ## Process

# %%
# %%time
convert_corpus(docs)
init_model()
for i in tqdm(range(n_iters)):
    BOW.apply(lambda x: gibbs_sample(x.name[0], x.name[1]), 1)
# Out:
# 100%|██████████| 5000/5000 [01:21<00:00, 61.04it/s]
# CPU times: user 1min 20s, sys: 4.74 s, total: 1min 25s
# Wall time: 1min 21s

# %%
show_results()
# Out:
# --------------------------------------------------------------------------------
# topic_id         0     term_str
# term_id
# 0         0.222222         cute
# 2         0.111111      adopted
# 3         0.111111      hamster
# 4         0.111111  chinchillas
# 18        0.111111         look
# 17        0.111111    yesterday
# 15        0.111111      kittens
# 11        0.111111       kitten
# 12        0.000000         like
# 16        0.000000       sister
# --------------------------------------------------------------------------------
# topic_id         1  term_str
# term_id
# 1         0.153846  broccoli
# 10        0.076923    banana
# 8         0.076923     piece
# 16        0.076923    sister
# 14        0.076923  smoothie
# 13        0.076923       ate
# 12        0.076923      like
# 9         0.076923  munching
# 19        0.076923       eat
# 7         0.076923   spinach
# --------------------------------------------------------------------------------
# topic_id  0  1                                                doc
# doc_id
# 0         0  5  I ate a banana and a spinach smoothie for brea...
# 1         0  4                I like to eat broccoli and bananas.
# 2         3  0                  Chinchillas and kittens are cute.
# 3         3  1              My sister adopted a kitten yesterday.
# 4         3  3  Look at this cute hamster munching on a piece ...
# --------------------------------------------------------------------------------

# %%
(PHI / PHI.sum()).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_45156608_2e36_11ea_a0cf_8c859027f1b0row0_col0 {
#             background-color:  #023858;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row1_col1 {
#             background-color:  #023858;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row2_col0 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row2_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row3_col0 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row3_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row4_col0 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row4_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row5_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row5_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row6_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row6_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row7_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row7_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row8_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row8_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row9_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row9_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row10_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row10_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row11_col0 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row11_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row12_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row12_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row13_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row13_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row14_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row14_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row15_col0 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row15_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row16_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row16_col1 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row17_col0 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row17_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row18_col0 {
#             background-color:  #73a9cf;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row18_col1 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row19_col0 {
#             background-color:  #fff7fb;
#         }    #T_45156608_2e36_11ea_a0cf_8c859027f1b0row19_col1 {
#             background-color:  #73a9cf;
#         }</style>
# <table id="T_45156608_2e36_11ea_a0cf_8c859027f1b0" >
# <thead>    <tr>
#         <th class="index_name level0" >topic_id</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >term_id</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row0_col0" class="data row0 col0" >0.222222</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row0_col1" class="data row0 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row1_col0" class="data row1 col0" >0</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row1_col1" class="data row1 col1" >0.153846</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row2_col0" class="data row2 col0" >0.111111</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row2_col1" class="data row2 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row3_col0" class="data row3 col0" >0.111111</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row3_col1" class="data row3 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row4_col0" class="data row4 col0" >0.111111</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row4_col1" class="data row4 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row5_col0" class="data row5 col0" >0</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row5_col1" class="data row5 col1" >0.0769231</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row6_col0" class="data row6 col0" >0</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row6_col1" class="data row6 col1" >0.0769231</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row7_col0" class="data row7 col0" >0</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row7_col1" class="data row7 col1" >0.0769231</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row8_col0" class="data row8 col0" >0</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row8_col1" class="data row8 col1" >0.0769231</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row9_col0" class="data row9 col0" >0</td>
#         <td id="T_45156608_2e36_11ea_a0cf_8c859027f1b0row9_col1" class="data row9 col1" >0.0769231</td>
#     </tr>    <tr>
#         <th id="T_45156608_2e36_11ea_a0cf_8c859027f1b0level0_row10" class="row_heading leve

# %%
(THETA / THETA.sum()).T.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row0_col0 {
#             background-color:  #fff7fb;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row0_col1 {
#             background-color:  #023858;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row1_col1 {
#             background-color:  #023858;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row2_col0 {
#             background-color:  #023858;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row2_col1 {
#             background-color:  #fff7fb;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row3_col0 {
#             background-color:  #056faf;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row3_col1 {
#             background-color:  #d0d1e6;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row4_col0 {
#             background-color:  #73a9cf;
#         }    #T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row4_col1 {
#             background-color:  #73a9cf;
#         }</style>
# <table id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0" >
# <thead>    <tr>
#         <th class="index_name level0" >topic_id</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >doc_id</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row0_col0" class="data row0 col0" >0</td>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row0_col1" class="data row0 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row1_col0" class="data row1 col0" >0</td>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row1_col1" class="data row1 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row2_col0" class="data row2 col0" >1</td>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row2_col1" class="data row2 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row3_col0" class="data row3 col0" >0.75</td>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row3_col1" class="data row3 col1" >0.25</td>
#     </tr>    <tr>
#         <th id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row4_col0" class="data row4 col0" >0.5</td>
#         <td id="T_63d71f5a_2e36_11ea_ac88_8c859027f1b0row4_col1" class="data row4 col1" >0.5</td>
#     </tr></tbody>
# </table>
