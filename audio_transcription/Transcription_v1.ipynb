# %% [markdown]
# # Convert Videos to Text
#
# https://www.thepythoncode.com/article/using-speech-recognition-to-convert-speech-to-text-python

# %%
# pip install ffmpeg moviepy 
# pip install SpeechRecognition pydub

# %%
# Imports
import moviepy.editor as mp
import speech_recognition as sr
import os

# %%
def convert_mp4_to_wav(file_name, mp4_path, wav_path):
    '''
    Loads mp4 file and write to .wav file
    
    Inputs:
    - file_name: name of file (without extension)
    - mp4_path: path to folder for mp4 files
    - wav_path: path to folder for wav files
    
    Outputs:
    - Saves .wav file to wav_path
    '''
    # Load mp4 file
    orig_video = mp.VideoFileClip(mp4_path + file_name + ".mp4")
    # Write to wav file
    orig_video.audio.write_audiofile(wav_path + file_name + ".wav")

    return

# %%
def transcribe_video(file_name, mp4_path, wav_path, text_path):
    '''
    Use Speech Recongizer library to transcribe speech
    
    Inputs:
    - file_name: name of the file (without extension)
    - wav_path: path to folder for wav files
    - mp4_path: path to folder for mp4 files
    - text_path: path to folder for transcribed text files
    
    Outputs:
    - Saves transcribed text to text_path
    '''
    print(f'Working on {file_name}...')
    
    # Convert mp4 file to wav file
    print('Converting mp4 to wav...')
    convert_mp4_to_wav(file_name, mp4_path, wav_path)
    
    # Initialize the recognizer
    r = sr.Recognizer()
    
    # Open the audio file
    print('Transcribing...')
    
    with sr.AudioFile(wav_path + file_name + ".wav") as source:
        # Load audio data
        audio_data = r.record(source)
        # Convert from speech to text
        text = r.recognize_google(audio_data)

    # Write to text file
    with open(text_path + file_name + ".txt", "w") as text_file:
        text_file.write(text)
        
    print()
    return

# %%
# Paths to directories
mp4_path = 'MP4_Files/'
wav_path = 'WAV_Files/'
text_path = 'Text_Files_v1/'

# Create empty directories for wav and text files (if they don't exist)
if not os.path.exists(wav_path):
    os.makedirs(wav_path)
    
if not os.path.exists(text_path):
    os.makedirs(text_path)

# %%
# List of file names
file_list = os.listdir(mp4_path) # List all files in mp4 directory
# Updated list of files names
# remove extension and skip files that start with '.' (e.g. ipynb checkpoints)
file_list = [x.replace('.mp4', '')for x in file_list if x[0] != '.'] # Remove extension

# %%
# Transcribe all files in list
for file in file_list:
    transcribe_video(file, mp4_path, wav_path, text_path)
# Out:
# Working on 223_2.26.20_S_SC...
# Converting mp4 to wav...
# chunk:   2%|▏         | 174/7047 [00:00<00:03, 1735.42it/s, now=None]
# MoviePy - Writing audio in WAV_Files/223_2.26.20_S_SC.wav
# MoviePy - Done.
# Transcribing...
# result2:
# {   'alternative': [   {   'confidence': 0.9549064,
#                            'transcript': 'and start simulation hi class how '
#                                          'are you guys doing today how are you '
#                                          "I'm good thank you we're going to "
#                                          'talk about some Behavior '
#                                          'expectations for our classroom today '
#                                          'does anyone have one off the top of '
#                                          'their head that we should include in '
#                                          'our expectations for class are you '
#                                          'going to show up on time and like be '
#                                          "ready to work yeah thank you that's "
#                                          'a great one does everyone agree with '
#                                          'that does anyone else have something '
#                                          'to add hey well I mean so much '
#                                          'Behavior expectations yeah thank you '
#                                          "Emily we're going to keep our phones "
#                                          "away in class maybe that's another "
#                                          'expectation when we come ready for '
#                                          'class like will said that means that '
#                                          'we put our phones away like a really '
#                                          'cool idea expectations Mina and well '
#                                          "let's keep talking about Behavior "
#                                          'expectations what about using indoor '
#                                          'voices in the classroom do you guys '
#                                          'think that would be a good one to '
#                                          'include yeah definitely want to use '
#                                          'our indoor voices in the classroom '
#                                          'listen to each other thank you Jayla '
#                                          "that's great so another Behavior "
#                                          'expectation would be using our '
#                                          'indoor voices so thank you guys for '
#                                          'being doing a good job and listening '
#                                          'to what Jayla said that could be '
#                                          'another expectation that we should '
#                                          'always remember to be quiet when '
#                                          'other people are speaking in class '
#                                          'Carlos awesome when someone else is '
#                                          "speaking yes we'll get to listen to "
#                                          "each other and it's pretty oh no "
#                                          "it's always better in a conversation "
#                                          "if we're listening yeah yeah well "
#                                          "wait a minute so we're talking about "
#                                          "Behavior expectations because it's a "
#                                          'great way for us all to be on the '
#                                          'same page so that our class will run '
#                                          'smoothly and everyone will be '
#                                          'respectful of each other and our '
#                                          'time and our classroom tools so '
#                                          "that's that's why we're doing this "
#                                          'please Behavior expectations my '
#                                          "expectation is you don't lie about "
#                                          'me stealing things well my '
#                                          "expectation thank you so we've come "
#                                          'up with some awesome Behavior '
#                                          'expectations for our class we talked '
#                                          'about listening when each other when '
#                                          'another person is speaking we talk '
#                                          'about using our indoor voices '
#                                          'respecting each other and showing up '
#                                          'on time for class I think that this '
#                                          'is an awesome list of behavior '
#                                          'expectations correct so did anyone '
#                                          'do anything fun over the weekend '
#                                          'that they want to share'},
#                        {   'transcript': 'and start simulation hi class how '
#                                          'are you guys doing today how are you '
#                                          "I'm good thank you we're going to "
#                                          'talk about some Behavior '
#                                          'expectations for our classroom today '
#                                          'does anyone have one off the top of '
#                                          'their head that we should include in '
#                                          'our expectations for class are you '
#                                          'going to show up on time and like be '
#                                          "ready to work yeah thank you that's "
#                                          'a great one does everyone agree with '
#                                          'that does anyone else have something '
#                                          'to add hey well I mean so much '
#                                          'Behavior expectations yeah thank you '
#                                          "Emily we're going to keep our phones "
#                                          "away in class maybe that's another "
#                                          'expectation when we come ready for '
#                                          'class like will said that means that '
#                                          'we put our phones away like a really '
#                                          'cool idea expectations Nina and will '
#                                          "let's keep talking about Behavior "
#                                          'expectations what about using indoor '
#                                          'voices in the classroom do you guys '
#                                          'think that would be a good one to '
#                                          'include yeah definitely want to use '
#                                          'our indoor voices in the classroom '
#                                          'listen to each other thank you Jayla '
#                                          "that's great so another Behavior "
#                                          'expectation would be using our '
#                                          'indoor voices so thank you guys for '
#                                          'being doing a good job and listening '
#                                          'to what Jayla said that could be '
#                                          'another expectation that we should '
#                                          'always remember to be quiet when '
#                                          'other people are speaking in class '
#                                          'Carlos awesome when someone else is '
#                                          "speaking yes we'll get to listen to "
#                                          "each other and it's pretty oh no "
#                                          "it's always better in a conversation "
#                                          "if we're listening yeah yeah well "
#                                          "wait a minute so we're talking about "
#                                          "Behavior expectations because it's a "
#                                          'great way for us all to be on the '
#                                          'same page so that our class will run '
#                                          'smoothly and everyone will be '
#                                          'respectful of each other and our '
#                                          'time and our classroom tools so '
#                                          "that's that's why we're doing this "
#                                          'please Behavior expectations my '
#                                          "expectation is you don't lie about "
#                                          'me stealing things well my '
#                                          "expectation thank you so we've come "
#                                          'up with some awesome Behavior '
#                                          'expectations for our class we talked '
#                                          'about listening when each other when '
#                                          'another person is speaking we talk '
#                                          'about using our indoor voices '
#                                          'respecting each other and showing up '
#                                          'on time for class I think that this '
#                                          'is an awesome list of behavior '
#                                          'expectations correct so did anyone '
#                                          'do anything fun over the weekend '
#                                          'that they want to share'},
#                        {   'transcript': 'and start simulation hi class how '
#                                          'are you guys doing today how are you '
#                                          "I'm good thank you we're going to "
#                                          'talk about some Behavior '
#                                          'expectations for our classroom today '
#                                          'does anyone have one off the top of '
#                                          'their head that we should include in '
#                                          'our expectations for class are you '
#                                          'going to show up on time and like be '
#                                          "ready to work yeah thank you that's "
#                                          'a great one does everyone agree with '
#                                          'that does anyone else have something '
#                                          'to add hey well I mean so much '
#                                          'Behavior expectations yeah thank you '
#                                          "Emily we're going to keep our phones "
#                                          "away in class maybe that's another "
#                                          'expectation when we come ready for '
#                                          'class like will said that means that '
#                                          'we put our phones away like a really '
#                                          'cool idea expectations Nina and well '
#                                          "let's keep talking about Behavior "
#                                          'expectations what about using indoor '
#                                          'voices in the classroom do you guys '
#                                          'think that would be a good one to '
#                                          'include yeah definitely want to use '
#                                          'our indoor voices in the classroom '
#                                          'listen to each other thank you Jayla '
#                                          "that's great so another Behavior "
#                                          'expectation would be using our '
#                                          'indoor voices so thank you guys for '
#                                          'being doing a good job and listening '
#                                          'to what Jayla said that could be '
#                                          'another expectation that we should '
#                                          'always remember to be quiet when '
#                                          'other people are speaking in class '
#                                          'Carlos awesome when someone else is '
#                                          "speaking yes we'll get to listen to "
#                                          "each other and it's pretty oh no "
#                                          "it's always better in a conversation "
#                                          "if we're listening yeah yeah well "
#                                          "wait a minute so we're talking about "
#                                          "Behavior expectations because it's a "
#                                          'great way for us all to be on the '
#                                          'same page so that our class will run '
#                                          'smoothly and everyone will be '
#                                          'respectful of each other and our '
#                                          'time and our classroom tools so '
#                                          "that's that's why we're doing this "
#                                          'please Behavior expectations my '
#                                          "expectation is you don't lie about "
#                                          'me stealing things well my '
#                                          "expectation thank you so we've come "
#                                          'up with some awesome Behavior '
#                                          'expectations for our class we talked '
#                                          'about listening when each other when '
#                                          'another person is speaking we talk '
#                                          'about using our indoor voices '
#                                          'respecting each other and showing up '
#                                          'on time for class I think that this '
#                                          'is an awesome list of behavior '
#                                          'expectations correct so did anyone '
#                                          'do anything fun over the weekend '
#                                          'that they want to share'},
#                        {   'transcript': 'and start simulation hi class how '
#                                          'are you guys doing today how are you '
#                                          "I'm good thank you we're going to "
#                                          'talk about some Behavior '
#                                          'expectations for our classroom today '
#                                          'does anyone have one off the top of '
#                                          'their head that we should include in '
#                                          'our expectations for class are you '
#                                          'going to show up on time and like be '
#                                          "ready to work yeah thank you that's "
#                                          'a great one does everyone agree with '
#                                          'that does anyone else have something '
#                                          'to add hey well I mean so much '
#                                          'Behavior expectations yeah thank you '
#                                          "Emily we're going to keep our phones "
#                                          "away in class maybe that's another "
#                                          'expectation when we come ready for '
#                                          'class like will said that means that '
#                                          'we put our phones away like a really '
#                                          'cool idea expectations Mina and well '
#                                          "let's keep talking about Behavior "
#                                          'expectations what about using indoor '
#                                          'voices in the classroom do you guys '
#                                          'think that would be a good one to '
#                                          'include yeah definitely why we want '
#                                          'to use our indoor voices in the '
#                                          'classroom listen to each other thank '
#                                          "you Jayla that's great so another "
#                                          'Behavior expectation would be using '
#                                          'our indoor voices so thank you guys '
#                                          'for being doing a good job and '
#                                          'listening to what Jayla said that '
#                                          'could be another expectation that we '
#                                          'should always remember to be quiet '
#                                          'when other people are speaking in '
#                                          'class Carlos awesome when someone '
#                                          "else is speaking yes we'll get to "
#                                          "listen to each other and it's pretty "
#                                          "oh no it's always better in a "
#                                          "conversation if we're listening yeah "
#                                          "yeah well wait a minute so we're "
#                                          'talking about Behavior expectations '
#                                          "because it's a great way for us all "
#                                          'to be on the same page so that our '
#                                          'class will run smoothly and everyone '
#                                          'will be respectful of each other and '
#                                          'our time and our classroom tools so '
#                                          "that's that's why we're doing this "
#                                          'please Behavior expectations my '
#                                          "expectation is you don't lie about "
#                                          'me stealing things well my '
#                                          "expectation thank you so we've come "
#                                          'up with some awesome Behavior '
#                                          'expectations for our class we talked '
#                                          'about listening when each other when '
#                                          'another person is speaking we talk '
#                                          'about using our indoor voices '
#                                          'respecting each other and showing up '
#                                          'on time for class I think that this '
#                                          'is an awesome list of behavior '
#                                          'expectations correct so did anyone '
#                                          'do anything fun over the weekend '
#                                          'that they want to share'},
#                        {   'transcript': 'and start simulation hi class how '
#                                          'are you guys doing today how are you '
#                                          "I'm good thank you we're going to "
#                                          'talk about some Behavior '
#                                          'expectations for our classroom today '
#                                          'does anyone have one off the top of '
#                                          'their head that we should include in '
#                                          'our expectations for class are you '
#                                          'going to show up on time and like be '
#                                          "ready to work yeah thank you that's "
#                                          'a great one does everyone agree with '
#                                          'that does anyone else have something '
#                                          'to add hey well I mean so much '
#                                          'Behavior expectations yeah thank you '
#                                          "Emily we're going to keep our phones "
#                                          "away in class maybe that's another "
#                                          'expectation when we come ready for '
#                                          'class like will said that means that '
#                                          'we put our phones away like a really '
#                                          'cool idea expectations Mina and will '
#                                          "let's keep talking about Behavior "
#                                          'expectations what about using indoor '
#                                          'voices in the classroom do you guys '
#                                          'think that would be a good one to '
#                                          'include yeah definitely want to use '
#                                          'our indoor voices in the classroom '
#                                          'listen to each other thank you Jayla '
#                                          "that's great so another Behavior "
#                                          'expectation would be using our '
#                                          'indoor voices so thank you guys for '
#                                          'being doing a good job and listening '
#                                          'to what Jayla said that could be '
#                                          'another expectation that we should '
#                                          'always remember to be quiet when '
#                                          'other people are speaking in class '
#                                          'Carlos awesome when someone else is '
#                                          "speaking yes we'll get to listen to "
#                                          "each other and it's pretty oh no "
#                                          "it's always better in a conversation "
#                                          "if we're listening yeah yeah well "
#                                          "wait a minute so we're talking about "
#                                          "Behavior expectations because it's a "
#                                          'great way for us all to be on the '
#                                          'same page so that our class will run '
#                                          'smoothly and everyone will be '
#                                          'respectful of each other and our '
#                                          'time and our classroom tools so '
#                                          "that's that's why we're doing this "
#                                          'please Behavior expectations my '
#                                          "expectation is you don't lie about "
#                                          'me stealing things well my '
#                                          "expectation thank you so we've come "
#                                          'up with some awesome Behavior '
#                                          'expectations for our class we talked '
#                                          'about listening when each other when '
#                                          'another person is speaking we talk '
#                                          'about using our indoor voices '
#                                          'respecting each other and showing up '
#                                          'on time for class I think that this '
#                                          'is an awesome list of behavior '
#                                          'expectations correct so did anyone '
#                                          'do anything fun over the weekend '
#                                          'that they want to share'}],
#     'final': True}
#
# Working on 210_1.31.20_S_SC...
# Converting mp4 to wav...
# chunk:   4%|▎         | 253/6877 [00:00<00:02, 2455.92it/s, now=None]
# MoviePy - Writing audio in WAV_Files/210_1.31.20_S_SC.wav
# MoviePy - Done.
# Transcribing...
# result2:
# {   'alternative': [   {   'confidence': 0.9429642,
#                            'transcript': 'begin simulation good afternoon '
#                                          "class how are we doing today I'm "
#                                          "fine thank you it's great to have "
#                                          'all of you with me today we are a '
#                                          'couple weeks into the semester but I '
#                                          'thought it would be a good idea for '
#                                          'us to review some of our classroom '
#                                          'Norms so I want to get right into it '
#                                          'so I want to remind you guys that '
#                                          'one of our first classrooms or '
#                                          'something to contribute why do you '
#                                          'think we decided that that was a '
#                                          'good classroom to have well you know '
#                                          'as I hear someone talking while '
#                                          "we're waiting for someone and that "
#                                          'would mean to not talk when someone '
#                                          "else's talking or to just give "
#                                          'someone a couple minutes to get '
#                                          'their thoughts together before they '
#                                          "decide to contribute it's okay oh "
#                                          'yeah another one of our classroom '
#                                          "knows like I just said it's about "
#                                          'being respectful and one of the ways '
#                                          'that we can be respectful to each '
#                                          'other in our class but our teachers '
#                                          'is by not using our phones in class '
#                                          'Emily thank you so much I appreciate '
#                                          'it sorry who was one of the first '
#                                          'classroom North that we talked about '
#                                          "just now I'm sorry science junkie I "
#                                          'would love to hear what you have to '
#                                          "say but I'd like feet yeah I was "
#                                          'just saying science I love science '
#                                          'as well why do you love science so '
#                                          'much Karma can you remind me of one '
#                                          'of the classroom Norms that we just '
#                                          'talked about yes and how can we show '
#                                          'Carlos wonderful thank you so can we '
#                                          'give Carlos the floor one more time '
#                                          'so you can tell her why he loves '
#                                          "science so much for like if you're "
#                                          'doing a lot of science fair going '
#                                          'forward that would be wonderful '
#                                          'Carlos does anyone else have any '
#                                          'contributions that they want to make '
#                                          'to this yeah Yes Juliet that is and '
#                                          'so that ties into our respect for '
#                                          'one another right you want to make '
#                                          'sure that when someone is talking '
#                                          "we're giving them and divided "
#                                          "attention we're doing this so that "
#                                          'we can proceed in a quarterly '
#                                          'fashion offer our classes and just '
#                                          "to make sure that we're all on the "
#                                          'same page going forward does anyone '
#                                          'want to tell me about something fun '
#                                          'that they learned in their previous '
#                                          'class well is there something that '
#                                          "you'd like to contribute or is there "
#                                          "someone that's not being responsible "
#                                          'or you guys using kind words no no I '
#                                          'think we agree with that right she '
#                                          'just stop Emily effort'},
#                        {   'transcript': 'begin simulation good afternoon '
#                                          "class how are we doing today I'm "
#                                          "fine thank you it's great to have "
#                                          'all of you with me today we are a '
#                                          'couple weeks into the semester but I '
#                                          'thought it would be a good idea for '
#                                          'us to review some of our classroom '
#                                          'Norms so I want to get right into it '
#                                          'so I want to remind you guys that '
#                                          'one of our first classrooms or '
#                                          'something to contribute why do you '
#                                          'think we decided that that was a '
#                                          'good classroom to have well you know '
#                                          'as I hear someone talking while '
#                                          "we're waiting for someone and that "
#                                          'would mean to not talk when someone '
#                                          "else's talking or to just give "
#                                          'someone a couple minutes to get '
#                                          'their thoughts together before they '
#                                          "decide to contribute it's okay oh "
#                                          'yeah another one of our classroom '
#                                          "knows like I just said it's about "
#                                          'being respectful and one of the ways '
#                                          'that we can be respectful to each '
#                                          'other in our class but our teachers '
#                                          'is by not using our phones in class '
#                                          'Emily thank you so much I appreciate '
#                                          'it sorry who was one of the first '
#                                          'classroom North that we talked about '
#                                          "just now I'm sorry science junkie I "
#                                          'would love to hear what you have to '
#                                          "say but I'd like feet yeah I was "
#                                          'just saying science I love science '
#                                          'as well why do you love science so '
#                                          'much Karma can you remind me of one '
#                                          'of the classroom Norms that we just '
#                                          'talked about yes and how can we show '
#                                          'Carlos wonderful thank you so can we '
#                                          'give Carlos the floor one more time '
#                                          'so you can tell her why he loves '
#                                          'science so much for like a lot of '
#                                          'science fair going forward that '
#                                          'would be wonderful Carlos does '
#                                          'anyone else have any contributions '
#                                          'that they want to make to this yeah '
#                                          'Yes Juliet that is and so that ties '
#                                          'into our respect for one another '
#                                          'right you want to make sure that '
#                                          "when someone is talking we're giving "
#                                          "them and divided attention we're "
#                                          'doing this so that we can proceed in '
#                                          'a quarterly fashion offer our '
#                                          'classes and just to make sure that '
#                                          "we're all on the same page going "
#                                          'forward does anyone want to tell me '
#                                          'about something fun that they '
#                                          'learned in their previous class well '
#                                          "is there something that you'd like "
#                                          'to contribute or is there someone '
#                                          "that's not being responsible or you "
#                                          'guys using kind words no no I think '
#                                          'we agree with that right she just '
#                                          'stop Emily effort'},
#                        {   'transcript': 'begin simulation good afternoon '
#                                          "class how are we doing today I'm "
#                                          "fine thank you it's great to have "
#                                          'all of you with me today we are a '
#                                          'couple weeks into the semester but I '
#                                          'thought it would be a good idea for '
#                                          'us to review some of our classroom '
#                                          'Norms so I want to get right into it '
#                                          'so I want to remind you guys that '
#                                          'one of our first classrooms or '
#                                          'something to contribute why do you '
#                                          'think we decided that that was a '
#                                          'good classroom to have well you know '
#                                          'as I hear someone talking while '
#                                          "we're waiting for someone and that "
#                                          'would mean to not talk when someone '
#                                          "else's talking or to just give "
#                                          'someone a couple minutes to get '
#                                          'their thoughts together before they '
#                                          "decide to contribute it's okay oh "
#                                          'yeah another one of our classroom '
#                                          "knows like I just said it's about "
#                                          'being respectful and one of the ways '
#                                          'that we can be respectful to each '
#                                          'other in our class but our teachers '
#                                          'is by not using our phones in class '
#                                          'Emily thank you so much I appreciate '
#                                          'it who was one of the first '
#                                          'classroom North that we talked about '
#                                          "just now I'm sorry science junkie I "
#                                          'would love to hear what you have to '
#                                          "say but I'd like feet yeah I was "
#                                          'just saying science I love science '
#                                          'as well why do you love science so '
#                                          'much Karma can you remind me of one '
#                                          'of the classroom Norms that we just '
#                                          'talked about yes and how can we show '
#                                          'Carlos wonderful thank you so can we '
#                                          'give Carlos the floor one more time '
#                                          'so you can tell her why he loves '
#                                          "science so much for like if you're "
#                                          'doing a lot of science fair going '
#                                          'forward that would be wonderful '
#                                          'Carlos does anyone else have any '
#                                          'contributions that they want to make '
#                                          'to this yeah Yes Juliet that is and '
#                                          'so that ties into our respect for '
#                                          'one another right you want to make '
#                                          'sure that when someone is talking '
#                                          "we're giving them and divided "
#                                          "attention we're doing this so that "
#                                          'we can proceed in a quarterly '
#                                          'fashion offer our classes and just '
#                                          "to make sure that we're all on the "
#                                          'same page going forward does anyone '
#                                          'want to tell me about something fun '
#                                          'that they learned in their previous '
#                                          'class well is there something that '
#                                          "you'd like to contribute or is there "
#                                          "someone that's not being responsible "
#                                          'or you guys using kind words no no I '
#                                          'think we agree with that right she '
#                                          'just stop Emily effort'},
#                        {   'transcript': 'begin simulation good afternoon '
#                                          "class how are we doing today I'm "
#                                          "fine thank you it's great to have "
#                                          'all of you with me today we are a '
#                                          'couple weeks into the semester but I '
#                                          'thought it would be a good idea for '
#                                          'us to review some of our classroom '
#                                          'Norms so I want to get right into it '
#                                          'so I want to remind you guys that '
#                                          'one of our first classroom or '
#                                          'something to contribute why do you '
#                                          'think we decided that that was a '
#                                          'good classroom to have well you know '
#                                          'as I hear someone talking while '
#                                          "we're waiting for someone and that "
#                                          'would mean to not talk when someone '
#                                          "else's talking or to just give "
#                                          'someone a couple minutes to get '
#                                          'their thoughts together before they '
#                                          "decide to contribute it's okay oh "
#                                          'yeah another one of our classroom '
#                                          "knows like I just said it's about "
#                                          'being respectful and one of the ways '
#                                          'that we can be respectful to each '
#                                          'other in our class but our teachers '
#                                          'is by not using our phones in class '
#                                          'Emily thank you so much I appreciate '
#                                          'it sorry who was one of the first '
#                                          'classroom North that we talked about '
#                                          "just now I'm sorry science junkie I "
#                                          'would love to hear what you have to '
#                                          "say but I'd like feet yeah I was "
#                                          'just saying science I love science '
#                                          'as well why do you love science so '
#                                          'much Karma can you remind me of one '
#                                          'of the classroom Norms that we just '
#                                          'talked about yes and how can we show '
#                                          'Carlos wonderful thank you so can we '
#                                          'give Carlos the floor one more time '
#                                          'so you can tell her why he loves '
#                                          "science so much for like if you're "
#                                          'doing a lot of science fair going '
#                                          'forward that would be wonderful '
#                                          'Carlos does anyone else have any '
#                                          'contributions that they want to make '
#                                          'to this yeah Yes Juliet that is and '
#                                          'so that ties into our respect for '
#                                          'one another right you want to make '
#                                          'sure that when someone is talking '
#                                          "we're giving them and divided "
#                                          "attention we're doing this so that "
#                                          'we can proceed in a quarterly '
#                                          'fashion offer our classes and just '
#                                          "to make sure that we're all on the "
#                                          'same page going forward does anyone '
#                                          'want to tell me about something fun '
#                                          'that they learned in their previous '
#                                          'class well is there something that '
#                                          "you'd like to contribute or is there "
#                                          "someone that's not being responsible "
#                                          'or you guys using kind words no no I '
#                                          'think we agree with that right she '
#                                          'just stop Emily effort'},
#                        {   'transcript': 'begin simulation good afternoon '
#                                          "class how are we doing today I'm "
#                                          "fine thank you it's great to have "
#                                          'all of you with me today we are a '
#                                          'couple weeks into the semester but I '
#                                          'thought it would be a good idea for '
#                                          'us to review some of our classroom '
#                                          'Norms so I want to get right into it '
#                                          'so I want to remind you guys that '
#                                          'one of our first classrooms or '
#                                          'something to contribute why do you '
#                                          'think we decided that that was a '
#                                          'good classroom to have well you know '
#                                          'as I hear someone talking while '
#                                          "we're waiting for someone and that "
#                                          'would mean to not talk when someone '
#                                          "else's talking or to just give "
#                                          'someone a couple minutes to get '
#                                          'their thoughts together before they '
#                                          "decide to contribute it's okay oh "
#                                          'yeah another one of our classroom '
#                                          "knows like I just said it's about "
#                                          'being respectful and one of the ways '
#                                          'that we can be respectful to each '
#                                          'other in our class but our teachers '
#                                          'is by not using our phones in class '
#                                          'Emily thank you so much I appreciate '
#                                          'it who was one of the first '
#                                          'classroom North that we talked about '
#                                          "just now I'm sorry science junkie I "
#                                          'would love to hear what you have to '
#                                          "say but I'd like feet yeah I was "
#                                          'just saying science I love science '
#                                          'as well why do you love science so '
#                                          'much Karma can you remind me of one '
#                                          'of the classroom Norms that we just '
# ...
#                                          'what is it to you to be kind I think '
#                                          'well being able to like listen to '
#                                          "other people's opinions maybe you "
#                                          "don't agree with right yeah so even "
#                                          'if you disagree with someone well '
#                                          'yeah well please be quiet thank you '
#                                          "well I mean I will talk after we're "
#                                          'done so the last one is be polite '
#                                          'what does it mean to be polite like '
#                                          "your turn like if you're waiting in "
#                                          'line like yeah helping people who '
#                                          'need help so if you have something '
#                                          'to share with the class you could '
#                                          'raise your hand and simulation'},
#                        {   'transcript': 'hello class hello hi my name is Miss '
#                                          'golf how are you okay I am doing '
#                                          "well so today we're going to talk "
#                                          'about setting some classroom '
#                                          'expectations so the first one is to '
#                                          'be respectful so raise your hand if '
#                                          'you think you know what that means '
#                                          "where's my pen you took it I didn't "
#                                          'picture picture Meena do you know '
#                                          'what that means to be respectful be '
#                                          "nice to other people who don't steal "
#                                          'your thanks so yes so be respectful '
#                                          'means being nice to other people '
#                                          'what about what people which people '
#                                          'should you be nice to in the '
#                                          'classroom well everybody yes so your '
#                                          'classmates and your teacher Emily '
#                                          'please turn your cell phone off '
#                                          'thank you besides people what other '
#                                          'things should be we consider when '
#                                          "we're being respectful should you "
#                                          'leave a mess in your classroom space '
#                                          "Carlos let's talk about that at the "
#                                          'end of class all right so the next '
#                                          'one is be responsible so what does '
#                                          'it mean to be responsible as a '
#                                          'student so being responsible what '
#                                          'does that mean to you besides not '
#                                          'stealing from your classmates I '
#                                          "would say doing your work I'm trying "
#                                          'participating stuff like that yeah '
#                                          'and coming to class prepared what is '
#                                          'what does it mean to be coming to '
#                                          'class prepared what should you have '
#                                          'and what else what else did you have '
#                                          'well what else did you have besides '
#                                          'your homework or your reading '
#                                          'conversations and stuff about the '
#                                          'material or whatever yeah so be '
#                                          'ready to share and contribute to '
#                                          'conversations you should also bring '
#                                          "a pen or a pencil case I'm just "
#                                          'excited so the next one is be kind '
#                                          'what does it mean to be kind Emily '
#                                          'within another people talk and to '
#                                          'know so Jayla we are doing this so '
#                                          'that everyone knows how to behave in '
#                                          'the classroom and so that we can all '
#                                          'work together as a community yeah so '
#                                          'what is it to you to be kind I think '
#                                          'well being able to like listen to '
#                                          "other people's opinions maybe you "
#                                          "don't agree with right yeah so even "
#                                          'if you disagree with someone well '
#                                          'yeah well please be quiet thank you '
#                                          "well I mean I will talk after we're "
#                                          'done so the last one is be polite '
#                                          'what does it mean to be polite like '
#                                          "your turn like if you're waiting in "
#                                          'line yeah helping people who need '
#                                          'help so if you have something to '
#                                          'share with the class you could raise '
#                                          'your hand and simulation'},
#                        {   'transcript': 'hello class hello hi my name is Miss '
#                                          'golf how are you okay I am doing '
#                                          "well so today we're going to talk "
#                                          'about setting some classroom '
#                                          'expectations so the first one is to '
#                                          'be respectful so raise your hand if '
#                                          'you think you know what that means '
#                                          "where's my pen you took it I didn't "
#                                          'picture picture Meena do you know '
#                                          'what that means to be respectful '
#                                          'like be nice to other people who '
#                                          "don't steal your thanks so yes so be "
#                                          'respectful means being nice to other '
#                                          'people what about what people which '
#                                          'people should you be nice to in the '
#                                          'classroom well everybody yes so your '
#                                          'classmates and your teacher Emily '
#                                          'please turn your cell phone off '
#                                          'thank you besides people what other '
#                                          'things should be we consider when '
#                                          "we're being respectful should you "
#                                          'leave a mess in your classroom space '
#                                          "Carlos let's talk about that at the "
#                                          'end of class all right so the next '
#                                          'one is be responsible so what does '
#                                          'it mean to be responsible as a '
#                                          'student so being responsible what '
#                                          'does that mean to you besides not '
#                                          'stealing from your classmates I '
#                                          "would say doing your work I'm trying "
#                                          'participating stuff like that yeah '
#                                          'and coming to class prepared what is '
#                                          'what does it mean to be coming to '
#                                          'class prepared what should you have '
#                                          'what else what else do you have well '
#                                          'what else did you have besides your '
#                                          'homework or your reading '
#                                          'conversations and stuff about the '
#                                          'material or whatever yeah so be '
#                                          'ready to share and contribute to '
#                                          'conversations you should also bring '
#                                          "a pen or a pencil case I'm just "
#                                          'excited so the next one is be kind '
#                                          'what does it mean to be kind Emily '
#                                          'within another people talk and to '
#                                          'know so Jayla we are doing this so '
#                                          'that everyone knows how to behave in '
#                                          'the classroom and so that we can all '
#                                          'work together as a community yeah so '
#                                          'what is it to you to be kind I think '
#                                          'well being able to like listen to '
#                                          "other people's opinions maybe you "
#                                          "don't agree with right yeah so even "
#                                          'if you disagree with someone well '
#                                          'yeah well please be quiet thank you '
#                                          "well I mean I will talk after we're "
#                                          'done so the last one is be polite '
#                                          'what does it mean to be polite like '
#                                          "your turn like if you're waiting in "
#                                          'line yeah helping people who need '
#                                          'help so if you have something to '
#                                          'share with the class you could raise '
#                                          'your hand and simulation'},
#                        {   'transcript': 'hello class hello hi my name is Miss '
#                                          'golf how are you okay I am doing '
#                                          "well so today we're going to talk "
#                                          'about setting some classroom '
#                                          'expectations so the first one is to '
#                                          'be respectful so raise your hand if '
#                                          'you think you know what that means '
#                                          "where's my pen you took it I didn't "
#                                          'picture picture Meena do you know '
#                                          'what that means to be respectful be '
#                                          "nice to other people who don't steal "
#                                          'your thanks so yes so be respectful '
#                                          'means being nice to other people '
#                                          'what about what people which people '
#                                          'should you be nice to in the '
#                                          'classroom well everybody yes so your '
#                                          'classmates and your teacher Emily '
#                                          'please turn your cell phone off '
#                                          'thank you besides people what other '
#                                          'things should be we consider when '
#                                          "we're being respectful should you "
#                                          'leave a mess in your classroom space '
#                                          "Carlos let's talk about that at the "
#                                          'end of class all right so the next '
#                                          'one is be responsible so what does '
#                                          'it mean to be responsible as a '
#                                          'student so being responsible what '
#                                          'does that mean to you besides not '
#                                          'stealing from your classmates I '
#                                          "would say doing your work I'm trying "
#                                          'participating stuff like that yeah '
#                                          'and coming to class prepared what is '
#                                          'what does it mean to be coming to '
#                                          'class prepared what should you have '
#                                          'and what else what else did you have '
#                                          'well what else did you have besides '
#                                          'your homework or your reading '
#                                          'conversations and stuff about the '
#                                          'material or whatever yeah so be '
#                                          'ready to share and contribute to '
#                                          'conversations you should also bring '
#                                          "a pen or a pencil case I'm just "
#                                          'excited so the next one is be kind '
#                                          'what does it mean to be kind Emily '
#                                          'within another people talk and to '
#                                          'know so Jayla we are doing this so '
#                                          'that everyone knows how to behave in '
#                                          'the classroom and so that we can all '
#                                          'work together as a community yeah so '
#                                          'what is it to you to be kind I think '
#                                          'well being able to like listen to '
#                                          "other people's opinions maybe you "
#                                          "don't agree with right yeah so even "
#                                          'if you disagree with someone well '
#                                          'yeah well please be quiet thank you '
#                                          "well I mean I will talk after we're "
#                                          'done so the last one is be polite '
#                                          'what does it mean to be polite like '
#                                          "your turn like if you're waiting in "
#                                          'line like yeah helping people who '
#                                          'need help so if you have something '
#                                          'to share with the class you could '
#                                          'raise your hand and simulation'}],
#     'final': True}

# %% [markdown]
# ### Test 2: Google Cloud Speech API
#
# This requires credentials.

# %%
temp_file = wav_path + file_list[0] + '.wav'

# %%
# use the audio file as the audio source
r = sr.Recognizer()
with sr.AudioFile(temp_file) as source:
    audio = r.record(source)  # read the entire audio file

# %%
# recognize speech using Google Cloud Speech
GOOGLE_CLOUD_SPEECH_CREDENTIALS = 'Archive/google_secret_key.json'
try:
    print("Google Cloud Speech thinks you said " + r.recognize_google_cloud(audio, credentials_json=GOOGLE_CLOUD_SPEECH_CREDENTIALS))
except sr.UnknownValueError:
    print("Google Cloud Speech could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Cloud Speech service; {0}".format(e))
# Out:
# Could not request results from Google Cloud Speech service; 400 Sync input too long. For audio longer than 1 min use LongRunningRecognize with a 'uri' parameter.

# %% [markdown]
# Does not work on audio longer than 1 minute. Would need to upload files to google cloud storage to transcribe them. Found this article that seems helful. This option would allow us to use the speaker diarization functionality. There is a cost associated with the storage and using the API, but it is free to start.
#
# https://towardsdatascience.com/how-to-use-google-speech-to-text-api-to-transcribe-long-audio-files-1c886f4eb3e9
