# %% [markdown]
# # Audio Feature Engineering
#
# This file contains all of the code used to extract speech/audio features for our analysis

# %%
import os

# %%
# Functions are save in a .py file
from speech_feature_extraction import *

# %% [markdown]
# ## Setup

# %%
# File paths
m4a_path = './data/m4a_files/' # Original audio files from sponsor
wav_path = './data/wav_files/' # Full wav files
transcript_path = './data/transcript_files/' # Transcripts from temi (downloaded as .txt column format with speaker numbers and timestamps)
teacher_wav_path = './data/teacher_wav_files/' # Teacher only wav files

# %%
# Create empty directories for output files (if it doesn't exist)
if not os.path.exists(wav_path):
    os.makedirs(wav_path)
    
# Create empty directory for teacher only wav files (if it doesn't exist)
if not os.path.exists(teacher_wav_path):
    os.makedirs(teacher_wav_path)

# %%
# List of file names
file_list = os.listdir(m4a_path) # List all files in original directory
# Updated list of files names
# remove extension and skip files that start with '.' (e.g. ipynb checkpoints)
file_list = [x.replace('.m4a', '')for x in file_list if '.m4a' in x] # Remove extension

# %%
# # Temporarily testing on a small list of files
# file_list = file_list[0:2]

# %%
# Print length of file_list (expected number of files/participants)
print(len(file_list))
# Out:
# 89

# %%
# Check that we have a transcript file for all of these
transript_file_list = [x.replace('.txt', '')for x in os.listdir(transcript_path) if '.txt' in x] 
for file in file_list:
    if file not in transript_file_list:
        print(file)

# %% [markdown]
# ## 1. Convert Audio Files to Wav Files

# %%
# Convert all audio files to wav format
for file in file_list:
    convert_m4a_to_wav(file, m4a_path, wav_path)

# %%
# Check that we have a wav file for all original files
wav_file_list = [x.replace('.wav', '')for x in os.listdir(wav_path) if '.wav' in x] 

assert len(file_list) == len(wav_file_list)
for file in file_list:
    if file not in wav_file_list:
        print(file)

# %% [markdown]
# ## 2. Extract Only the Teacher's Audio
#
# Using timestamps from Temi transcriptions to cut out the avatar voices to get a .wav file with just the teacher's audio.

# %%
# Get lookup of teacher speaker numbers
speaker_num_df = pd.read_excel('../speaker_identification.xlsx')
speaker_num_dict = dict(zip(speaker_num_df.file_name, speaker_num_df.teacher))
speaker_num_dict['348th_11.4.21.txt'] = speaker_num_dict['348_11.4.21.txt'] # manual update for one weird file name

# %%
# Extract just the teacher's audio into new wav file
for file in file_list:
    extract_teacher_audio(file, wav_path, teacher_wav_path, transcript_path, speaker_num_dict[file + '.txt'])

# %%
# Check that we have a teacher only file for all original files
teacher_audio_file_list = [x.replace('.wav', '')for x in os.listdir(teacher_wav_path) if '.wav' in x] 

assert len(file_list) == len(teacher_audio_file_list)
for file in file_list:
    if file not in teacher_audio_file_list:
        print(file)

# %% [markdown]
# ## 3. Extract Features from Transcripts
#
# Exploring some feature creation from the transcript files such as:
# - **Duration** including duration in seconds (total, teacher, and student), average duration (total, teacher, and student), and percent of the time that the teacher is the speaker.
# - **Word count** including total count (total, teacher, and student), percent of words said by teacher, and word rate (total, teacher, and student).
# - **Line count** (aka number of changes in speakers) including number of speaker changes (total line count) and number of time student/teacher speaks (student/teacher line count).
#
#
# These features could be used to analyze the frequency of student interruptions, speed of speech, and balance of talking between teacher and students.

# %%
# Create empty dataframe to save transcript features
transcript_features = pd.DataFrame()

# %%
# Extract transcript features
for file in file_list:
    try:
        # Extract features
        temp_df, temp_df_summary = extract_transcript_features(file, transcript_path, wav_path, speaker_num_dict[file + '.txt'])
        # Add features to final dataframe
        transcript_features = pd.concat([transcript_features, temp_df_summary])
    except:
        print(f'Problem with {file}')
# Out:
# /Users/Kaia/Desktop/Capstone/capstone/speech_features/speech_feature_extraction.py:236: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[-1]['Timestamp_Pairs'] = (df.iloc[-1]['Timestamp_Pairs'][0], duration)

# %%
transcript_features
# Out:
#      ID  Total_Duration  Teacher_Duration  Student_Duration  \
# 0   332      308.563991             141.0        167.563991
# 0   348      309.289320              86.0        223.289320
# 0   335      313.918662             145.0        168.918662
# 0   320      308.307982             180.0        128.307982
# 0   328      315.305329             202.0        113.305329
# ..  ...             ...               ...               ...
# 0   218      318.203379             194.0        124.203379
# 0   223      319.588413             204.0        115.588413
# 0   347      306.451995             191.0        115.451995
# 0   360      319.870658             190.0        129.870658
# 0   221      312.390771             184.0        128.390771
#
#     Percent_Time_Teacher  Average_Speaker_Duration  Average_Teacher_Duration  \
# 0               0.456955                  9.075411                  8.294118
# 0               0.278057                  6.580624                  3.739130
# 0               0.461903                  6.975970                  6.590909
# 0               0.583832                  5.817132                  6.923077
# 0               0.640649                  7.332682                  9.619048
# ..                   ...                       ...                       ...
# 0               0.609673                  7.761058                  9.238095
# 0               0.638321                  7.432289                  9.714286
# 0               0.623262                  8.282486                 10.611111
# 0               0.593990                  6.527973                  7.916667
# 0               0.589006                  7.437875                  9.200000
#
#     Average_Student_Duration  Total_Word_Count  Teacher_Word_Count  \
# 0                   9.856705               697                 305
# 0                   9.303722               698                 195
# 0                   7.344290              1021                 567
# 0                   4.752147               651                 407
# 0                   5.150242               856                 637
# ..                       ...               ...                 ...
# 0                   6.210169               803                 602
# 0                   5.254019               868                 583
# 0                   6.076421               975                 684
# 0                   5.194826               643                 435
# 0                   5.835944               734                 494
#
#     Student_Word_Count  Teacher_Percent_Words  Total_Word_Rate  \
# 0                  392               0.437590         2.258851
# 0                  503               0.279370         2.256787
# 0                  454               0.555338         3.252435
# 0                  244               0.625192         2.111525
# 0                  219               0.744159         2.714829
# ..                 ...                    ...              ...
# 0                  201               0.749689         2.523543
# 0                  285               0.671659         2.715993
# 0                  291               0.701538         3.181575
# 0                  208               0.676516         2.010188
# 0                  240               0.673025         2.349621
#
#     Teacher_Word_Rate  Student_Word_Rate  Total_Speaker_Line_Count  \
# 0            2.163121           2.339405                        34
# 0            2.267442           2.252683                        47
# 0            3.910345           2.687684                        45
# 0            2.261111           1.901674                        53
# 0            3.153465           1.932831                        43
# ..                ...                ...                       ...
# 0            3.103093           1.618313                        41
# 0            2.857843           2.465645                        43
# 0            3.581152           2.520528                        37
# 0            2.289474           1.601593                        49
# 0            2.684783           1.869293                        42
#
#     Teacher_Line_Count  Student_Line_Count
# 0                   17                  17
# 0                   23                  24
# 0                   22                  23
# 0                   26                  27
# 0                   21                  22
# ..                 ...                 ...
# 0                   21                  20
# 0                   21                  22
# 0                   18                  19
# 0                   24                  25
# 0                   20                  22
#
# [89 rows x 18 columns]

# %%
assert transcript_features.shape[0] == len(file_list)

# %% [markdown]
# ## 4. Speech Feature Engineering

# %%
# Create empty dataframe to save audio features
audio_features = pd.DataFrame()

# %%
for file in file_list:
    try:
        # Extract features
        temp_df_summary = extract_audio_features(file, teacher_wav_path, num_mfccs = 13)
        # Add features to final dataframe
        audio_features = pd.concat([audio_features, temp_df_summary])
    except:
        print(f'Problem with {file}')

# %%
audio_features
# Out:
#      ID number_ of_syllables number_of_pauses rate_of_speech  \
# 0   332                  411               62              3
# 0   348                  255               39              3
# 0   335                  427               87              3
# 0   320                  483               87              3
# 0   328                  614              105              3
# ..  ...                  ...              ...            ...
# 0   218                  314               42              3
# 0   223                  780               83              4
# 0   347                  693               84              4
# 0   360                  437               88              2
# 0   221                  609               90              3
#
#    articulation_rate speaking_duration original_duration balance f0_mean  \
# 0                  4              93.5             144.6     0.6  211.67
# 0                  5              50.5                86     0.6  244.32
# 0                  5              87.3               141     0.6  239.45
# 0                  4             108.2               180     0.6  218.64
# 0                  5             130.7               202     0.6  148.77
# ..               ...               ...               ...     ...     ...
# 0                  5              62.8                90     0.7  258.72
# 0                  5             154.1               204     0.8  224.38
# 0                  5             138.9               191     0.7  239.71
# 0                  5              94.1               190     0.5  151.52
# 0                  6             110.4               184     0.6  221.77
#
#    f0_std  ...  Flatness_Max Flatness_Std Zero_Crossing_Rate_Mean  \
# 0   53.96  ...  1.484376e-06     0.101342                0.106655
# 0   56.67  ...  2.166050e-06     0.168635                0.102524
# 0   66.01  ...  5.494624e-07     0.140694                0.100872
# 0   48.18  ...  1.154836e-06     0.134986                0.113569
# 0   45.43  ...  8.892575e-07     0.107515                0.101777
# ..    ...  ...           ...          ...                     ...
# 0   73.09  ...  1.595255e-06     0.009985                0.140677
# 0   43.21  ...  1.655184e-07     0.002108                0.075508
# 0   53.91  ...  5.416586e-07     0.092835                0.117964
# 0   54.59  ...  2.598544e-06     0.216559                0.087531
# 0   59.41  ...  1.671179e-07     0.011014                0.073442
#
#    Zero_Crossing_Rate_Min Zero_Crossing_Rate_Max Zero_Crossing_Rate_Std  \
# 0                0.724121                    0.0               0.111820
# 0                0.819824                    0.0               0.115759
# 0                0.642578                    0.0               0.102428
# 0                0.738281                    0.0               0.117673
# 0                0.606445                    0.0               0.098971
# ..                    ...                    ...                    ...
# 0                0.608398                    0.0               0.099093
# 0                0.522461                    0.0               0.061578
# 0                0.691406                    0.0               0.119356
# 0                0.575684                    0.0               0.089756
# 0                0.584961                    0.0               0.065982
#
#     Loudness_Mean  Loudness_Min  Loudness_Max  Loudness_Std
# 0      -41.060013    -12.580391    -92.580391     19.036415
# 0      -43.753429    -14.232292    -94.232292     21.297735
# 0      -41.438087    -12.843327    -92.843323     23.901451
# 0      -43.237362    -16.844372    -96.844376     19.977518
# 0      -42.857697    -16.831387    -96.831390     18.386736
# ..            ...           ...           ...           ...
# 0      -32.689915    -11.363259    -67.924858     13.973388
# 0      -33.415398    -13.524834    -72.490852     13.480139
# 0      -36.221664    -13.817157    -93.817154     18.311182
# 0      -50.064537    -14.589852    -94.589851     24.071793
# 0      -42.878002    -16.035614    -73.801910     13.369958
#
# [89 rows x 92 columns]

# %%
assert audio_features.shape[0] == len(file_list)

# %% [markdown]
# ## 4. Combine Features into Single Dataframe

# %%
# Merge the two dataframes with features into one
df = transcript_features.merge(audio_features, on = 'ID')

# %%
df
# Out:
#      ID  Total_Duration  Teacher_Duration  Student_Duration  \
# 0   332      308.563991             141.0        167.563991
# 1   348      309.289320              86.0        223.289320
# 2   335      313.918662             145.0        168.918662
# 3   320      308.307982             180.0        128.307982
# 4   328      315.305329             202.0        113.305329
# ..  ...             ...               ...               ...
# 84  218      318.203379             194.0        124.203379
# 85  223      319.588413             204.0        115.588413
# 86  347      306.451995             191.0        115.451995
# 87  360      319.870658             190.0        129.870658
# 88  221      312.390771             184.0        128.390771
#
#     Percent_Time_Teacher  Average_Speaker_Duration  Average_Teacher_Duration  \
# 0               0.456955                  9.075411                  8.294118
# 1               0.278057                  6.580624                  3.739130
# 2               0.461903                  6.975970                  6.590909
# 3               0.583832                  5.817132                  6.923077
# 4               0.640649                  7.332682                  9.619048
# ..                   ...                       ...                       ...
# 84              0.609673                  7.761058                  9.238095
# 85              0.638321                  7.432289                  9.714286
# 86              0.623262                  8.282486                 10.611111
# 87              0.593990                  6.527973                  7.916667
# 88              0.589006                  7.437875                  9.200000
#
#     Average_Student_Duration  Total_Word_Count  Teacher_Word_Count  ...  \
# 0                   9.856705               697                 305  ...
# 1                   9.303722               698                 195  ...
# 2                   7.344290              1021                 567  ...
# 3                   4.752147               651                 407  ...
# 4                   5.150242               856                 637  ...
# ..                       ...               ...                 ...  ...
# 84                  6.210169               803                 602  ...
# 85                  5.254019               868                 583  ...
# 86                  6.076421               975                 684  ...
# 87                  5.194826               643                 435  ...
# 88                  5.835944               734                 494  ...
#
#     Flatness_Max  Flatness_Std  Zero_Crossing_Rate_Mean  \
# 0   1.484376e-06      0.101342                 0.106655
# 1   2.166050e-06      0.168635                 0.102524
# 2   5.494624e-07      0.140694                 0.100872
# 3   1.154836e-06      0.134986                 0.113569
# 4   8.892575e-07      0.107515                 0.101777
# ..           ...           ...                      ...
# 84  1.595255e-06      0.009985                 0.140677
# 85  1.655184e-07      0.002108                 0.075508
# 86  5.416586e-07      0.092835                 0.117964
# 87  2.598544e-06      0.216559                 0.087531
# 88  1.671179e-07      0.011014                 0.073442
#
#     Zero_Crossing_Rate_Min  Zero_Crossing_Rate_Max  Zero_Crossing_Rate_Std  \
# 0                 0.724121                     0.0                0.111820
# 1                 0.819824                     0.0                0.115759
# 2                 0.642578                     0.0                0.102428
# 3                 0.738281                     0.0                0.117673
# 4                 0.606445                     0.0                0.098971
# ..                     ...                     ...                     ...
# 84                0.608398                     0.0                0.099093
# 85                0.522461                     0.0                0.061578
# 86                0.691406                     0.0                0.119356
# 87                0.575684                     0.0                0.089756
# 88                0.584961                     0.0                0.065982
#
#     Loudness_Mean  Loudness_Min Loudness_Max Loudness_Std
# 0      -41.060013    -12.580391   -92.580391    19.036415
# 1      -43.753429    -14.232292   -94.232292    21.297735
# 2      -41.438087    -12.843327   -92.843323    23.901451
# 3      -43.237362    -16.844372   -96.844376    19.977518
# 4      -42.857697    -16.831387   -96.831390    18.386736
# ..            ...           ...          ...          ...
# 84     -32.689915    -11.363259   -67.924858    13.973388
# 85     -33.415398    -13.524834   -72.490852    13.480139
# 86     -36.221664    -13.817157   -93.817154    18.311182
# 87     -50.064537    -14.589852   -94.589851    24.071793
# 88     -42.878002    -16.035614   -73.801910    13.369958
#
# [89 rows x 109 columns]

# %%
# Save to csv file for further analysis
df.to_csv('Teacher_Mindfulness_Audio_Transcript_Features_20230214.csv', index = False)
